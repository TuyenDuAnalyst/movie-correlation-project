# %%
#Import libraries

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use ('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjust the configuration of the plots we will create

#Read in the data

df = pd.read_csv('/content/movies.csv')

# %%
# Let's look at the data

df.head()
# Out:
#                                              name  ... runtime
# 0                                     The Shining  ...   146.0
# 1                                 The Blue Lagoon  ...   104.0
# 2  Star Wars: Episode V - The Empire Strikes Back  ...   124.0
# 3                                       Airplane!  ...    88.0
# 4                                      Caddyshack  ...    98.0
#
# [5 rows x 15 columns]

# %%
#Let's see if there is any missing data
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
# dropping the rows having NaN values
df =df.dropna()

# %%
# Data types for our columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change data type of columns

df['budget'] = df['budget'].astype('int64')
df['gross'] = df['gross'].astype('int64')

# %%
df
# Out:
#                                                 name  ... runtime
# 0                                        The Shining  ...   146.0
# 1                                    The Blue Lagoon  ...   104.0
# 2     Star Wars: Episode V - The Empire Strikes Back  ...   124.0
# 3                                          Airplane!  ...    88.0
# 4                                         Caddyshack  ...    98.0
# ...                                              ...  ...     ...
# 7648                               Bad Boys for Life  ...   124.0
# 7649                              Sonic the Hedgehog  ...    99.0
# 7650                                        Dolittle  ...   101.0
# 7651                            The Call of the Wild  ...   100.0
# 7652                               The Eight Hundred  ...   149.0
#
# [5421 rows x 15 columns]

# %%
#Create correct Year column
df["yearcorrect"] = df['released'].astype(str).str.split(" ", expand=True)[2]
df
# Out:
#                                                 name  ... yearcorrect
# 0                                        The Shining  ...        1980
# 1                                    The Blue Lagoon  ...        1980
# 2     Star Wars: Episode V - The Empire Strikes Back  ...        1980
# 3                                          Airplane!  ...        1980
# 4                                         Caddyshack  ...        1980
# ...                                              ...  ...         ...
# 7648                               Bad Boys for Life  ...        2020
# 7649                              Sonic the Hedgehog  ...        2020
# 7650                                        Dolittle  ...        2020
# 7651                            The Call of the Wild  ...        2020
# 7652                               The Eight Hundred  ...        2020
#
# [5421 rows x 16 columns]

# %%
df =df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
pd.set_options('display.max_rows', None)

# %%
# Drop any duplicated

df.drop_duplicates()
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 4007                               i5 Films
# 6793                             i am OTHER
# 6420                                   erbp
#                        ...
# 385                        1818 Productions
# 2929                          1492 Pictures
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# Name: company, Length: 1475, dtype: object

# %%
df
# Out:
#                                                 name  ... yearcorrect
# 0                                        The Shining  ...        1980
# 1                                    The Blue Lagoon  ...        1980
# 2     Star Wars: Episode V - The Empire Strikes Back  ...        1980
# 3                                          Airplane!  ...        1980
# 4                                         Caddyshack  ...        1980
# ...                                              ...  ...         ...
# 7648                               Bad Boys for Life  ...        2020
# 7649                              Sonic the Hedgehog  ...        2020
# 7650                                        Dolittle  ...        2020
# 7651                            The Call of the Wild  ...        2020
# 7652                               The Eight Hundred  ...        2020
#
# [5421 rows x 16 columns]

# %%
# Budget high correlation
# company high correlation

# %%
#Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earning')
plt.ylabel('Budget for Film')
plt.show()

# %%
df.head()
# Out:
#                                             name rating  ... runtime  yearcorrect
# 5445                                      Avatar  PG-13  ...   162.0         2009
# 7445                           Avengers: Endgame  PG-13  ...   181.0         2019
# 3045                                     Titanic  PG-13  ...   194.0         1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  ...   138.0         2015
# 7244                      Avengers: Infinity War  PG-13  ...   149.0         2018
#
# [5 rows x 16 columns]

# %%
# Plot budget vs gross using seaborn

sns.regplot (x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color": "blue"})

# %%
#Let's start looking at correlation

# %%
df.corr(method='pearson') #pearson, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
#High correlation between budget and gross
# I was right

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot =True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#Look at company

df.head()
# Out:
#                                             name rating  ... runtime  yearcorrect
# 5445                                      Avatar  PG-13  ...   162.0         2009
# 7445                           Avengers: Endgame  PG-13  ...   181.0         2019
# 3045                                     Titanic  PG-13  ...   194.0         1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  ...   138.0         2015
# 7244                      Avengers: Infinity War  PG-13  ...   149.0         2018
#
# [5 rows x 16 columns]

# %%
df_numerized = df

for col_name in df_numerized.columns:
  if (df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes

df_numerized
# Out:
#       name  rating  genre  year  ...       gross  company  runtime  yearcorrect
# 5445   386       5      0  2009  ...  2847246203     1382    162.0           31
# 7445   388       5      0  2019  ...  2797501328      983    181.0           41
# 3045  4909       5      6  1997  ...  2201647264     1382    194.0           19
# 6663  3643       5      0  2015  ...  2069521700      945    138.0           37
# 7244   389       5      0  2018  ...  2048359754      983    149.0           40
# ...    ...     ...    ...   ...  ...         ...      ...      ...          ...
# 5640  3794       6      6  2009  ...        5073     1385     96.0           37
# 2434  2969       5      0  1993  ...        2970     1376     97.0           16
# 3681  1595       3      6  2000  ...        2554      466    108.0           23
# 272   2909       6      9  1982  ...        2270      582     85.0            4
# 3203  4966       5      4  1997  ...         309      504     85.0           19
#
# [5421 rows x 16 columns]

# %%
df
# Out:
#       name  rating  genre  year  ...       gross  company  runtime  yearcorrect
# 5445   386       5      0  2009  ...  2847246203     1382    162.0           31
# 7445   388       5      0  2019  ...  2797501328      983    181.0           41
# 3045  4909       5      6  1997  ...  2201647264     1382    194.0           19
# 6663  3643       5      0  2015  ...  2069521700      945    138.0           37
# 7244   389       5      0  2018  ...  2048359754      983    149.0           40
# ...    ...     ...    ...   ...  ...         ...      ...      ...          ...
# 5640  3794       6      6  2009  ...        5073     1385     96.0           37
# 2434  2969       5      0  1993  ...        2970     1376     97.0           16
# 3681  1595       3      6  2000  ...        2554      466    108.0           23
# 272   2909       6      9  1982  ...        2270      582     85.0            4
# 3203  4966       5      4  1997  ...         309      504     85.0           19
#
# [5421 rows x 16 columns]

# %%
correlation_matrix = df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix, annot =True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numerized.corr()
# Out:
#                  name    rating     genre  ...   company   runtime  yearcorrect
# name         1.000000 -0.029234  0.010996  ...  0.021697  0.010850     0.026784
# rating      -0.029234  1.000000  0.147796  ... -0.092357  0.140792     0.019749
# genre        0.010996  0.147796  1.000000  ... -0.071334 -0.059237    -0.067962
# year         0.025542  0.019499 -0.073167  ... -0.014333  0.075077     0.994821
# released    -0.006152  0.018083  0.022142  ... -0.002407  0.008975    -0.008821
# score        0.014450  0.065983  0.035106  ...  0.020656  0.414068     0.061059
# votes        0.012615  0.006031 -0.135990  ...  0.118470  0.352303     0.202953
# director     0.015246  0.014656 -0.008553  ... -0.008223  0.017433    -0.035162
# writer       0.012880 -0.003149  0.017578  ... -0.003697 -0.017561    -0.022050
# star        -0.006882  0.009196  0.003341  ...  0.014082  0.010108    -0.031631
# country     -0.025490  0.008230 -0.009164  ...  0.048569 -0.034477    -0.071611
# budget       0.023392 -0.203946 -0.368523  ...  0.170235  0.318695     0.320216
# gross        0.005639 -0.181906 -0.244101  ...  0.149553  0.275796     0.268367
# company      0.021697 -0.092357 -0.071334  ...  1.000000  0.037585    -0.016150
# runtime      0.010850  0.140792 -0.059237  ...  0.037585  1.000000     0.076203
# yearcorrect  0.026784  0.019749 -0.067962  ... -0.016150  0.076203     1.000000
#
# [16 rows x 16 columns]

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.029234
#              genre          0.010996
#              year           0.025542
#              released      -0.006152
#                               ...
# yearcorrect  budget         0.320216
#              gross          0.268367
#              company       -0.016150
#              runtime        0.076203
#              yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.368523
# budget       genre         -0.368523
# gross        genre         -0.244101
# genre        gross         -0.244101
# rating       budget        -0.203946
#                               ...
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# Length: 256, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# votes        gross          0.614751
# gross        votes          0.614751
#              budget         0.740247
# budget       gross          0.740247
# yearcorrect  year           0.994821
# year         yearcorrect    0.994821
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# score        score          1.000000
# released     released       1.000000
# year         year           1.000000
# genre        genre          1.000000
# rating       rating         1.000000
# runtime      runtime        1.000000
# yearcorrect  yearcorrect    1.000000
# dtype: float64

# %%
#Votes and budget have the highest correlation to gross earnings

#Company has low correlation
